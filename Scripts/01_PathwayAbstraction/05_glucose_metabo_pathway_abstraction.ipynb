# %%
from SPARQLWrapper import SPARQLWrapper, TURTLE, JSON, CSV
import subprocess
import time
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import glob
import itertools
import requests
import csv
from utility import *

# %%
current_directory = os.getcwd()
BioPAX_Ontology_file_path = os.path.join(current_directory, '../../Data/BioPAX/BioPAXOntology/biopax-level3.owl')
ReactomeBioPAX_file_path = os.path.join(current_directory, '../../Data/BioPAX/ReactomeBioPAX/Homo_sapiens_v96.owl')
metabolism_glucose = os.path.join(current_directory, '../../Data/BioPAX/ReactomeBioPAX/R-HSA-70326.owl')
PathwayAbstractionsFolder = os.path.join(current_directory, '../../Results/PathwayAbstraction')

prefixes = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>
"""
endpoint = "http://localhost:3030/glycolysis"

# %%
query_is_a_component_of = """
SELECT DISTINCT ?subPathwayID ?pathwayID
WHERE {
    # ?pathway rdf:type bp3:Pathway .
    # ?pathway bp3:pathwayComponent ?subPathway .
    # ?subPathway rdf:type bp3:Pathway .

    # ?pathway bp3:xref ?pathwayXref .
    # ?pathwayXref rdf:type bp3:UnificationXref .
    # ?pathwayXref bp3:db "Reactome" .
    # ?pathwayXref bp3:id ?pathwayID .
    
    # ?subPathway bp3:xref ?subPathwayXref .
    # ?subPathwayXref rdf:type bp3:UnificationXref .
    # ?subPathwayXref bp3:db "Reactome" .
    # ?subPathwayXref bp3:id ?subPathwayID .
}
"""

query_next_step_pathway = """
SELECT DISTINCT ?pathwayID ?nextPathwayID
WHERE {
    # ?pathway rdf:type bp3:Pathway .
    # ?nextPathway rdf:type bp3:Pathway .
    
    # ?pathway bp3:pathwayOrder ?pathwayStep .
    # ?nextPathway bp3:pathwayOrder ?nextStep .
    
    # ?pathwayStep bp3:nextStep ?nextStep .
    
    FILTER (?pathway != ?nextPathway)

    # ?pathway bp3:xref ?pathwayXref .
    # ?pathwayXref rdf:type bp3:UnificationXref .
    # ?pathwayXref bp3:db "Reactome" .
    # ?pathwayXref bp3:id ?pathwayID .
    
    # ?nextPathway bp3:xref ?nextPathwayXref .
    # ?nextPathwayXref rdf:type bp3:UnificationXref .
    # ?nextPathwayXref bp3:db "Reactome" .
    # ?nextPathwayXref bp3:id ?nextPathwayID .
}
"""

endpoint = "http://localhost:3030/glucose"
command = [
    '/home/cbeust/Softwares/JenaFuseki/apache-jena-fuseki-4.9.0/fuseki-server',
    '--file', metabolism_glucose,
    '--file', BioPAX_Ontology_file_path,
    '/glucose'
]
process = subprocess.Popen(command)
time.sleep(30)

sparql = SPARQLWrapper(endpoint)

sparql.setQuery(prefixes + query_is_a_component_of)
sparql.setReturnFormat(CSV)
try:
    results = sparql.query().convert()
    output_filename = os.path.join(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_IsAComponentOf.csv")
    with open(output_filename, 'wb') as f:
        f.write(results)
    print(f"Results saved in {output_filename}")
except Exception as e:
    print(f"Error in IsAComponentOf SPARQL query: {e}")
iscomponentof = pd.read_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_IsAComponentOf.csv", sep=",", header=0)
new_col = ["abstraction:IsAComponentOf"]*len(iscomponentof)
iscomponentof.insert(loc=1, column="interaction", value=new_col)
iscomponentof.to_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_IsAComponentOf.csv", sep=",", header=True, index=False)

sparql.setQuery(prefixes + query_next_step_pathway)
sparql.setReturnFormat(CSV)
try:
    results = sparql.query().convert()
    output_filename = os.path.join("../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NextStepPathway.csv")
    with open(output_filename, 'wb') as f:
        f.write(results)
    print(f"Results saved in {output_filename}")
except Exception as e:
    print(f"Error in NextStepPathway query: {e}")

nextsteppathway = pd.read_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NextStepPathway.csv", sep=",", header=0)
new_col = ["abstraction:NextStepPathway"]*len(nextsteppathway)
nextsteppathway.insert(loc=1, column="interaction", value=new_col)
nextsteppathway.to_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NextStepPathway.csv", sep=",", header=True, index=False)

try:
    q1 = pd.read_csv(os.path.join("../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_IsAComponentOf.csv"), header=None)
    q2 = pd.read_csv(os.path.join("../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NextStepPathway.csv"), header=None)
    q1 = q1.drop(0).reset_index(drop=True)
    q2 = q2.drop(0).reset_index(drop=True)
    concat_df = pd.concat([q1, q2], ignore_index=True)
    output_csv = os.path.join("../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_PathwayAbstraction.tsv")
    concat_df.to_csv(output_csv, sep=',', header=False, index=False)
    print(f"CSV output saved in {output_csv}")
except Exception as e:
    print(f"Error: {e}")

process.kill()
time.sleep(30)
# Out:
# 16:52:32 INFO  Server          :: Dataset: in-memory: load file: /home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/ReactomeBioPAX/R-HSA-70326.owl
# 16:52:32 INFO  Server          :: Dataset: in-memory: load file: /home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/BioPAXOntology/biopax-level3.owl
# 16:52:32 INFO  Server          :: Running in read-only mode for /glucose
# 16:52:32 INFO  Server          :: Apache Jena Fuseki 4.9.0
# 16:52:32 INFO  Config          :: FUSEKI_HOME=/home/cbeust/Softwares/JenaFuseki/apache-jena-fuseki-4.9.0
# 16:52:32 INFO  Config          :: FUSEKI_BASE=/home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/run
# 16:52:32 INFO  Config          :: Shiro file: file:///home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/run/shiro.ini
# 16:52:33 INFO  Server          :: Database: in-memory, with files loaded
# 16:52:33 INFO  Server          :: Path = /glucose
# 16:52:33 INFO  Server          ::   Memory: 16.0 GiB
# 16:52:33 INFO  Server          ::   Java:   17.0.17
# 16:52:33 INFO  Server          ::   OS:     Linux 7.1.3-101.fc43.x86_64 amd64
# 16:52:33 INFO  Server          ::   PID:    95559
# 16:52:33 INFO  Server          :: Started 2026/07/15 16:52:33 CEST on port 3030
# 16:53:01 INFO  Fuseki          :: [1] GET http://localhost:3030/glucose?query=%0APREFIX+rdf%3A+%3Chttp%3A//www.w3.org/1999/02/22-rdf-syntax-ns%23%3E%0APREFIX+rdfs%3A+%3Chttp%3A//www.w3.org/2000/01/rdf-schema%23%3E%0APREFIX+owl%3A+%3Chttp%3A//www.w3.org/2002/07/owl%23%3E%0APREFIX+bp3%3A+%3Chttp%3A//www.biopax.org/release/biopax-level3.owl%23%3E%0A%0ASELECT+DISTINCT+%3FsubPathwayID+%3FpathwayID%0AWHERE+%7B%0A++++%3Fpathway+rdf%3Atype+bp3%3APathway+.%0A++++%3Fpathway+bp3%3ApathwayComponent+%3FsubPathway+.%0A++++%3FsubPathway+rdf%3Atype+bp3%3APathway+.%0A%0A++++%3Fpathway+bp3%3Axref+%3FpathwayXref+.%0A++++%3FpathwayXref+rdf%3Atype+bp3%3AUnificationXref+.%0A++++%3FpathwayXref+bp3%3Adb+%22Reactome%22+.%0A++++%3FpathwayXref+bp3%3Aid+%3FpathwayID+.%0A++++%0A++++%3FsubPathway+bp3%3Axref+%3FsubPathwayXref+.%0A++++%3FsubPathwayXref+rdf%3Atype+bp3%3AUnificationXref+.%0A++++%3FsubPathwayXref+bp3%3Adb+%22Reactome%22+.%0A++++%3FsubPathwayXref+bp3%3Aid+%3FsubPathwayID+.%0A%7D%0A&format=csv&output=csv&results=csv
# 16:53:01 INFO  Fuseki          :: [1] Query =  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX owl: <http://www.w3.org/2002/07/owl#> PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>  SELECT DISTINCT ?subPathwayID ?pathwayID WHERE {     ?pathway rdf:type bp3:Pathway .     ?pathway bp3:pathwayComponent ?subPathway .     ?subPathway rdf:type bp3:Pathway .      ?pathway bp3:xref ?pathwayXref .     ?pathwayXref rdf:type bp3:UnificationXref .     ?pathwayXref bp3:db "Reactome" .     ?pathwayXref bp3:id ?pathwayID .          ?subPathway bp3:xref ?subPathwayXref .     ?subPathwayXref rdf:type bp3:UnificationXref .     ?subPathwayXref bp3:db "Reactome" .     ?subPathwayXref bp3:id ?subPathwayID . }
# 16:53:01 INFO  Fuseki          :: [1] 200 OK (48 ms)
# 16:53:01 INFO  Fuseki          :: [2] GET http://localhost:3030/glucose?query=%0APREFIX+rdf%3A+%3Chttp%3A//www.w3.org/1999/02/22-rdf-syntax-ns%23%3E%0APREFIX+rdfs%3A+%3Chttp%3A//www.w3.org/2000/01/rdf-schema%23%3E%0APREFIX+owl%3A+%3Chttp%3A//www.w3.org/2002/07/owl%23%3E%0APREFIX+bp3%3A+%3Chttp%3A//www.biopax.org/release/biopax-level3.owl%23%3E%0A%0ASELECT+DISTINCT+%3FpathwayID+%3FnextPathwayID%0AWHERE+%7B%0A++++%3Fpathway+rdf%3Atype+bp3%3APathway+.%0A++++%3FnextPathway+rdf%3Atype+bp3%3APathway+.%0A++++%0A++++%3Fpathway+bp3%3ApathwayOrder+%3FpathwayStep+.%0A++++%3FnextPathway+bp3%3ApathwayOrder+%3FnextStep+.%0A++++%0A++++%3FpathwayStep+bp3%3AnextStep+%3FnextStep+.%0A++++%0A++++FILTER+%28%3Fpathway+%21%3D+%3FnextPathway%29%0A%0A++++%3Fpathway+bp3%3Axref+%3FpathwayXref+.%0A++++%3FpathwayXref+rdf%3Atype+bp3%3AUnificationXref+.%0A++++%3FpathwayXref+bp3%3Adb+%22Reactome%22+.%0A++++%3FpathwayXref+bp3%3Aid+%3FpathwayID+.%0A++++%0A++++%3FnextPathway+bp3%3Axref+%3FnextPathwayXref+.%0A++++%3FnextPathwayXref+rdf%3Atype+bp3%3AUnificationXref+.%0A++++%3FnextPathwayXref+bp3%3Adb+%22Reactome%22+.%0A++++%3FnextPathwayXref+bp3%3Aid+%3FnextPathwayID+.%0A%7D%0A&format=csv&output=csv&results=csv
# 16:53:01 INFO  Fuseki          :: [2] Query =  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX owl: <http://www.w3.org/2002/07/owl#> PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>  SELECT DISTINCT ?pathwayID ?nextPathwayID WHERE {     ?pathway rdf:type bp3:Pathway .     ?nextPathway rdf:type bp3:Pathway .          ?pathway bp3:pathwayOrder ?pathwayStep .     ?nextPathway bp3:pathwayOrder ?nextStep .          ?pathwayStep bp3:nextStep ?nextStep .          FILTER (?pathway != ?nextPathway)      ?pathway bp3:xref ?pathwayXref .     ?pathwayXref rdf:type bp3:UnificationXref .     ?pathwayXref bp3:db "Reactome" .     ?pathwayXref bp3:id ?pathwayID .          ?nextPathway bp3:xref ?nextPathwayXref .     ?nextPathwayXref rdf:type bp3:UnificationXref .     ?nextPathwayXref bp3:db "Reactome" .     ?nextPathwayXref bp3:id ?nextPathwayID . }
# 16:53:02 INFO  Fuseki          :: [2] 200 OK (41 ms)
# Results saved in ../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_IsAComponentOf.csv
# Results saved in ../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NextStepPathway.csv
# CSV output saved in ../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_PathwayAbstraction.tsv

# %%
query_up_per_pathway = """ 
SELECT DISTINCT ?pathwayID ?entityID
WHERE {
    VALUES ?db { "UniProt" "UniProt Isoform" }

    # ?pathway rdf:type bp3:Pathway .
    # ?pathway (bp3:pathwayComponent | bp3:pathwayOrder/bp3:stepProcess)* ?interaction .
    # ?interaction rdf:type/(rdfs:subClassOf*) bp3:Interaction .
    # ?pathway bp3:xref ?pathwayXref .
    # ?pathwayXref rdf:type bp3:UnificationXref ;
                    bp3:db "Reactome" ;
                    bp3:id ?pathwayID .

    VALUES ?relation { bp3:left bp3:right bp3:participant bp3:controller }
    # ?interaction ?relation ?entity .
    
    # ?entity (bp3:component | bp3:memberPhysicalEntity)* ?entityCompo .

    # ?entityCompo rdf:type/(rdfs:subClassOf*) bp3:PhysicalEntity .
    # ?entityCompo bp3:entityReference ?entityRef .
    # ?entityRef bp3:xref ?entityRefXref .
    # ?entityRefXref rdf:type bp3:UnificationXref ;
                    bp3:db ?db ;
                    bp3:id ?entityID .
}
"""

query_nb_up_per_pathway = """ 
SELECT ?pathwayID (COUNT(DISTINCT ?entityID) AS ?nbID)
WHERE {
    VALUES ?db { "UniProt" "UniProt Isoform" }

    # ?pathway rdf:type bp3:Pathway .
    # ?pathway (bp3:pathwayComponent | bp3:pathwayOrder/bp3:stepProcess)* ?interaction .
    # ?interaction rdf:type/(rdfs:subClassOf*) bp3:Interaction .
    # ?pathway bp3:xref ?pathwayXref .
    # ?pathwayXref rdf:type bp3:UnificationXref ;
                    bp3:db "Reactome" ;
                    bp3:id ?pathwayID .

    VALUES ?relation { bp3:left bp3:right bp3:participant bp3:controller }
    # ?interaction ?relation ?entity .
    
    # ?entity (bp3:component | bp3:memberPhysicalEntity)* ?entityCompo .

    # ?entityCompo rdf:type/(rdfs:subClassOf*) bp3:PhysicalEntity .
    # ?entityCompo bp3:entityReference ?entityRef .
    # ?entityRef bp3:xref ?entityRefXref .
    # ?entityRefXref rdf:type bp3:UnificationXref ;
                    bp3:db ?db ;
                    bp3:id ?entityID .
}
GROUP BY ?pathwayID
"""

endpoint = "http://localhost:3030/glucose"

command = [
    '/home/cbeust/Softwares/JenaFuseki/apache-jena-fuseki-4.9.0/fuseki-server',
    '--file', metabolism_glucose,
    '--file', BioPAX_Ontology_file_path,
    '/glucose'
]
print("Fuseki command:", command)

process = subprocess.Popen(command)
time.sleep(30)

sparql = SPARQLWrapper(endpoint)

sparql.setQuery(prefixes + query_up_per_pathway)
sparql.setReturnFormat(CSV)
try:
    results = sparql.query().convert()
    output_filename = os.path.join("../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_UpPerPathway.csv")
    with open(output_filename, 'wb') as f:
        f.write(results)
    print(f"Results saved in {output_filename}")
except Exception as e:
    print(f"Error: {e}")

sparql.setQuery(prefixes + query_nb_up_per_pathway)
sparql.setReturnFormat(CSV)
try:
    results = sparql.query().convert()
    output_filename = os.path.join("../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NbUpPerPathway.csv")
    with open(output_filename, 'wb') as f:
        f.write(results)
    print(f"Results saved in {output_filename}")
except Exception as e:
    print(f"Error: {e}")

process.kill()
time.sleep(30)
# Out:
# Fuseki command: ['/home/cbeust/Softwares/JenaFuseki/apache-jena-fuseki-4.9.0/fuseki-server', '--file', '/home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/ReactomeBioPAX/R-HSA-70326.owl', '--file', '/home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/BioPAXOntology/biopax-level3.owl', '/glucose']
# 16:54:41 INFO  Server          :: Dataset: in-memory: load file: /home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/ReactomeBioPAX/R-HSA-70326.owl
# 16:54:42 INFO  Server          :: Dataset: in-memory: load file: /home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/BioPAXOntology/biopax-level3.owl
# 16:54:42 INFO  Server          :: Running in read-only mode for /glucose
# 16:54:43 INFO  Server          :: Apache Jena Fuseki 4.9.0
# 16:54:43 INFO  Config          :: FUSEKI_HOME=/home/cbeust/Softwares/JenaFuseki/apache-jena-fuseki-4.9.0
# 16:54:43 INFO  Config          :: FUSEKI_BASE=/home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/run
# 16:54:43 INFO  Config          :: Shiro file: file:///home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/run/shiro.ini
# 16:54:43 INFO  Server          :: Database: in-memory, with files loaded
# 16:54:43 INFO  Server          :: Path = /glucose
# 16:54:43 INFO  Server          ::   Memory: 16.0 GiB
# 16:54:43 INFO  Server          ::   Java:   17.0.17
# 16:54:43 INFO  Server          ::   OS:     Linux 7.1.3-101.fc43.x86_64 amd64
# 16:54:43 INFO  Server          ::   PID:    96181
# 16:54:43 INFO  Server          :: Started 2026/07/15 16:54:43 CEST on port 3030
# 16:55:10 INFO  Fuseki          :: [1] GET http://localhost:3030/glucose?query=%0APREFIX+rdf%3A+%3Chttp%3A//www.w3.org/1999/02/22-rdf-syntax-ns%23%3E%0APREFIX+rdfs%3A+%3Chttp%3A//www.w3.org/2000/01/rdf-schema%23%3E%0APREFIX+owl%3A+%3Chttp%3A//www.w3.org/2002/07/owl%23%3E%0APREFIX+bp3%3A+%3Chttp%3A//www.biopax.org/release/biopax-level3.owl%23%3E%0A+%0ASELECT+DISTINCT+%3FpathwayID+%3FentityID%0AWHERE+%7B%0A++++VALUES+%3Fdb+%7B+%22UniProt%22+%22UniProt+Isoform%22+%7D%0A%0A++++%3Fpathway+rdf%3Atype+bp3%3APathway+.%0A++++%3Fpathway+%28bp3%3ApathwayComponent+%7C+bp3%3ApathwayOrder/bp3%3AstepProcess%29%2A+%3Finteraction+.%0A++++%3Finteraction+rdf%3Atype/%28rdfs%3AsubClassOf%2A%29+bp3%3AInteraction+.%0A++++%3Fpathway+bp3%3Axref+%3FpathwayXref+.%0A++++%3FpathwayXref+rdf%3Atype+bp3%3AUnificationXref+%3B%0A++++++++++++++++++++bp3%3Adb+%22Reactome%22+%3B%0A++++++++++++++++++++bp3%3Aid+%3FpathwayID+.%0A%0A++++VALUES+%3Frelation+%7B+bp3%3Aleft+bp3%3Aright+bp3%3Aparticipant+bp3%3Acontroller+%7D%0A++++%3Finteraction+%3Frelation+%3Fentity+.%0A++++%0A++++%3Fentity+%28bp3%3Acomponent+%7C+bp3%3AmemberPhysicalEntity%29%2A+%3FentityCompo+.%0A%0A++++%3FentityCompo+rdf%3Atype/%28rdfs%3AsubClassOf%2A%29+bp3%3APhysicalEntity+.%0A++++%3FentityCompo+bp3%3AentityReference+%3FentityRef+.%0A++++%3FentityRef+bp3%3Axref+%3FentityRefXref+.%0A++++%3FentityRefXref+rdf%3Atype+bp3%3AUnificationXref+%3B%0A++++++++++++++++++++bp3%3Adb+%3Fdb+%3B%0A++++++++++++++++++++bp3%3Aid+%3FentityID+.%0A%7D%0A&format=csv&output=csv&results=csv
# 16:55:10 INFO  Fuseki          :: [1] Query =  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX owl: <http://www.w3.org/2002/07/owl#> PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>   SELECT DISTINCT ?pathwayID ?entityID WHERE {     VALUES ?db { "UniProt" "UniProt Isoform" }      ?pathway rdf:type bp3:Pathway .     ?pathway (bp3:pathwayComponent | bp3:pathwayOrder/bp3:stepProcess)* ?interaction .     ?interaction rdf:type/(rdfs:subClassOf*) bp3:Interaction .     ?pathway bp3:xref ?pathwayXref .     ?pathwayXref rdf:type bp3:UnificationXref ;                     bp3:db "Reactome" ;                     bp3:id ?pathwayID .      VALUES ?relation { bp3:left bp3:right bp3:participant bp3:controller }     ?interaction ?relation ?entity .          ?entity (bp3:component | bp3:memberPhysicalEntity)* ?entityCompo .      ?entityCompo rdf:type/(rdfs:subClassOf*) bp3:PhysicalEntity .     ?entityCompo bp3:entityReference ?entityRef .     ?entityRef bp3:xref ?entityRefXref .     ?entityRefXref rdf:type bp3:UnificationXref ;                     bp3:db ?db ;                     bp3:id ?entityID . }
# 16:55:11 INFO  Fuseki          :: [1] 200 OK (480 ms)
# 16:55:11 INFO  Fuseki          :: [2] GET http://localhost:3030/glucose?query=%0APREFIX+rdf%3A+%3Chttp%3A//www.w3.org/1999/02/22-rdf-syntax-ns%23%3E%0APREFIX+rdfs%3A+%3Chttp%3A//www.w3.org/2000/01/rdf-schema%23%3E%0APREFIX+owl%3A+%3Chttp%3A//www.w3.org/2002/07/owl%23%3E%0APREFIX+bp3%3A+%3Chttp%3A//www.biopax.org/release/biopax-level3.owl%23%3E%0A+%0ASELECT+%3FpathwayID+%28COUNT%28DISTINCT+%3FentityID%29+AS+%3FnbID%29%0AWHERE+%7B%0A++++VALUES+%3Fdb+%7B+%22UniProt%22+%22UniProt+Isoform%22+%7D%0A%0A++++%3Fpathway+rdf%3Atype+bp3%3APathway+.%0A++++%3Fpathway+%28bp3%3ApathwayComponent+%7C+bp3%3ApathwayOrder/bp3%3AstepProcess%29%2A+%3Finteraction+.%0A++++%3Finteraction+rdf%3Atype/%28rdfs%3AsubClassOf%2A%29+bp3%3AInteraction+.%0A++++%3Fpathway+bp3%3Axref+%3FpathwayXref+.%0A++++%3FpathwayXref+rdf%3Atype+bp3%3AUnificationXref+%3B%0A++++++++++++++++++++bp3%3Adb+%22Reactome%22+%3B%0A++++++++++++++++++++bp3%3Aid+%3FpathwayID+.%0A%0A++++VALUES+%3Frelation+%7B+bp3%3Aleft+bp3%3Aright+bp3%3Aparticipant+bp3%3Acontroller+%7D%0A++++%3Finteraction+%3Frelation+%3Fentity+.%0A++++%0A++++%3Fentity+%28bp3%3Acomponent+%7C+bp3%3AmemberPhysicalEntity%29%2A+%3FentityCompo+.%0A%0A++++%3FentityCompo+rdf%3Atype/%28rdfs%3AsubClassOf%2A%29+bp3%3APhysicalEntity+.%0A++++%3FentityCompo+bp3%3AentityReference+%3FentityRef+.%0A++++%3FentityRef+bp3%3Axref+%3FentityRefXref+.%0A++++%3FentityRefXref+rdf%3Atype+bp3%3AUnificationXref+%3B%0A++++++++++++++++++++bp3%3Adb+%3Fdb+%3B%0A++++++++++++++++++++bp3%3Aid+%3FentityID+.%0A%7D%0AGROUP+BY+%3FpathwayID%0A&format=csv&output=csv&results=csv
# 16:55:11 INFO  Fuseki          :: [2] Query =  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX owl: <http://www.w3.org/2002/07/owl#> PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>   SELECT ?pathwayID (COUNT(DISTINCT ?entityID) AS ?nbID) WHERE {     VALUES ?db { "UniProt" "UniProt Isoform" }      ?pathway rdf:type bp3:Pathway .     ?pathway (bp3:pathwayComponent | bp3:pathwayOrder/bp3:stepProcess)* ?interaction .     ?interaction rdf:type/(rdfs:subClassOf*) bp3:Interaction .     ?pathway bp3:xref ?pathwayXref .     ?pathwayXref rdf:type bp3:UnificationXref ;                     bp3:db "Reactome" ;                     bp3:id ?pathwayID .      VALUES ?relation { bp3:left bp3:right bp3:participant bp3:controller }     ?interaction ?relation ?entity .          ?entity (bp3:component | bp3:memberPhysicalEntity)* ?entityCompo .      ?entityCompo rdf:type/(rdfs:subClassOf*) bp3:PhysicalEntity .     ?entityCompo bp3:entityReference ?entityRef .     ?entityRef bp3:xref ?entityRefXref .     ?entityRefXref rdf:type bp3:UnificationXref ;                     bp3:db ?db ;                     bp3:id ?entityID . } GROUP BY ?pathwayID
# Results saved in ../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_UpPerPathway.csv
# 16:55:11 INFO  Fuseki          :: [2] 200 OK (289 ms)
# Results saved in ../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NbUpPerPathway.csv

# %%
query = """
SELECT (COUNT(DISTINCT ?id) AS ?nbID)
WHERE {
VALUES ?db { "UniProt" "UniProt Isoform" }
# ?entityRef rdf:type/(rdfs:subClassOf*) bp3:ProteinReference .
# ?entityRef bp3:xref ?entityRefXref .
# ?entityRefXref bp3:db ?db .
# ?entityRefXref bp3:id ?id .
}
"""

isacomponentof = pd.read_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_IsAComponentOf.csv", sep=',', header=0)
nextsteppathway = pd.read_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NextStepPathway.csv", sep=',', header=0)
G = create_networkx_graph(isacomponentof)
root = [node for node in G.nodes() if G.out_degree(node) == 0]

up_per_pathway = pd.read_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_UpPerPathway.csv", sep=",", header=0)

dico_er_per_pathway = dict()
for index, row in up_per_pathway.iterrows():
    pathway = row[0]
    id = row[1]
    if not pathway in dico_er_per_pathway.keys():
        dico_er_per_pathway[pathway] = [id]
    else:
        dico_er_per_pathway[pathway] += [id]

command = [
    '/home/cbeust/Softwares/JenaFuseki/apache-jena-fuseki-4.9.0/fuseki-server',
    '--file', metabolism_glucose,
    '--file', BioPAX_Ontology_file_path,
    '/glucose'
]
print("Fuseki command:", command)

process = subprocess.Popen(command)
time.sleep(30)
sparql = SPARQLWrapper(endpoint)
sparql.setQuery(prefixes + query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
nbEr_total = int(results["results"]["bindings"][0]["nbID"]["value"])
print(nbEr_total)

dico_isacomponentof_resnik_er = dict()
for index, row in isacomponentof.iterrows():
    pathway1 = row[0]
    pathway2 = row[2]
    interaction = row[1]
    if interaction == "abstraction:IsAComponentOf":
        score = resnik_similarity_ER(G, root[0], pathway1, pathway2, dico_er_per_pathway, nbEr_total)
        key = f"{str(pathway1)}-<>{str(pathway2)}"
        dico_isacomponentof_resnik_er[key] = score
print(dico_isacomponentof_resnik_er)

weighted_graph = pd.DataFrame(columns=['source', 'interaction', 'target', 'weight'])
counter_rows = 0
for index, row in isacomponentof.iterrows():
    weighted_graph.at[counter_rows, 'source'] = row[0]
    weighted_graph.at[counter_rows, 'interaction'] = row[1]
    weighted_graph.at[counter_rows, 'target'] = row[2]
    key = f'{str(row[0])}-<>{str(row[2])}'
    weight = dico_isacomponentof_resnik_er[key]
    weighted_graph.at[counter_rows, 'weight'] = weight
    counter_rows += 1

weighted_graph.to_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_IsAComponentOf_ResnikER.csv", sep=",", header=True, index=False)

process.kill()
time.sleep(30)

# WEIGHT NEXTSTEPPATHWAY EDGES
dico_next_step_er = dict()
distribution_weight_er = list()

for item, row in nextsteppathway.iterrows():
    if row[1] == "abstraction:NextStepPathway":
        Pathway1 = row[0]
        Pathway2 = row[2]
        key = f"{str(Pathway1)}->{str(Pathway2)}"
        weight_er = compute_similarity(Pathway1, Pathway2, dico_er_per_pathway, nbEr_total)
        distribution_weight_er.append(weight_er)
        dico_next_step_er[key] = weight_er

weighted_graph = pd.DataFrame(columns=['source', 'interaction', 'target', 'weight'])
counter_rows = 0
for item, row in nextsteppathway.iterrows():
    if row[1] == "abstraction:NextStepPathway":
        weighted_graph.at[counter_rows, 'source'] = row[0]
        weighted_graph.at[counter_rows, 'interaction'] = row[1]
        weighted_graph.at[counter_rows, 'target'] = row[2]
        key = f"{str(row[0])}->{str(row[2])}"
        weight = dico_next_step_er[key]
        weighted_graph.at[counter_rows, 'weight'] = weight
    counter_rows += 1
weighted_graph.to_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NextStepPathway_ERcontent.csv", sep=",", header=True, index=False)

# CONCATENATE GRAPHS
weighted_is_a_component_of = pd.read_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_IsAComponentOf_ResnikER.csv", sep=",", header=0)
print(weighted_is_a_component_of.head())

weighted_next_step_pathway = pd.read_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_NextStepPathway_ERcontent.csv", sep=",", header=0)
print(weighted_next_step_pathway.head())

global_abstraction = pd.concat([weighted_is_a_component_of, weighted_next_step_pathway], axis=0)
global_abstraction.to_csv(f"../../Results/PathwayAbstraction/04_MetabolismGlucose/R-HSA-70326_WeightedPathwayAbstraction.csv", sep=",", index=False)
# Out:
# Pathway abstraction loaded in networkx:
# Fuseki command: ['/home/cbeust/Softwares/JenaFuseki/apache-jena-fuseki-4.9.0/fuseki-server', '--file', '/home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/ReactomeBioPAX/R-HSA-70326.owl', '--file', '/home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/BioPAXOntology/biopax-level3.owl', '/glucose']
# /tmp/ipykernel_92593/2564248583.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pathway = row[0]
# /tmp/ipykernel_92593/2564248583.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   id = row[1]
# 16:55:51 INFO  Server          :: Dataset: in-memory: load file: /home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/ReactomeBioPAX/R-HSA-70326.owl
# 16:55:52 INFO  Server          :: Dataset: in-memory: load file: /home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/../../Data/BioPAX/BioPAXOntology/biopax-level3.owl
# 16:55:52 INFO  Server          :: Running in read-only mode for /glucose
# 16:55:53 INFO  Server          :: Apache Jena Fuseki 4.9.0
# 16:55:53 INFO  Config          :: FUSEKI_HOME=/home/cbeust/Softwares/JenaFuseki/apache-jena-fuseki-4.9.0
# 16:55:53 INFO  Config          :: FUSEKI_BASE=/home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/run
# 16:55:53 INFO  Config          :: Shiro file: file:///home/cbeust/Projects/2026/AbstractionReactomeTopPathways/Scripts/01_PathwayAbstraction/run/shiro.ini
# 16:55:53 INFO  Server          :: Database: in-memory, with files loaded
# 16:55:53 INFO  Server          :: Path = /glucose
# 16:55:53 INFO  Server          ::   Memory: 16.0 GiB
# 16:55:53 INFO  Server          ::   Java:   17.0.17
# 16:55:53 INFO  Server          ::   OS:     Linux 7.1.3-101.fc43.x86_64 amd64
# 16:55:53 INFO  Server          ::   PID:    96384
# 16:55:53 INFO  Server          :: Started 2026/07/15 16:55:53 CEST on port 3030
# 16:56:20 INFO  Fuseki          :: [1] GET http://localhost:3030/glucose?query=%0APREFIX+rdf%3A+%3Chttp%3A//www.w3.org/1999/02/22-rdf-syntax-ns%23%3E%0APREFIX+rdfs%3A+%3Chttp%3A//www.w3.org/2000/01/rdf-schema%23%3E%0APREFIX+owl%3A+%3Chttp%3A//www.w3.org/2002/07/owl%23%3E%0APREFIX+bp3%3A+%3Chttp%3A//www.biopax.org/release/biopax-level3.owl%23%3E%0A%0ASELECT+%28COUNT%28DISTINCT+%3Fid%29+AS+%3FnbID%29%0AWHERE+%7B%0AVALUES+%3Fdb+%7B+%22UniProt%22+%22UniProt+Isoform%22+%7D%0A%3FentityRef+rdf%3Atype/%28rdfs%3AsubClassOf%2A%29+bp3%3AProteinReference+.%0A%3FentityRef+bp3%3Axref+%3FentityRefXref+.%0A%3FentityRefXref+bp3%3Adb+%3Fdb+.%0A%3FentityRefXref+bp3%3Aid+%3Fid+.%0A%7D%0A&format=json&output=json&results=json
# 16:56:20 INFO  Fuseki          :: [1] Query =  PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX owl: <http://www.w3.org/2002/07/owl#> PREFIX bp3: <http://www.biopax.org/release/biopax-level3.owl#>  SELECT (COUNT(DISTINCT ?id) AS ?nbID) WHERE { VALUES ?db { "UniProt" "UniProt Isoform" } ?entityRef rdf:type/(rdfs:subClassOf*) bp3:ProteinReference . ?entityRef bp3:xref ?entityRefXref . ?entityRefXref bp3:db ?db . ?entityRefXref bp3:id ?id . }
# 16:56:21 INFO  Fuseki          :: [1] 200 OK (66 ms)
# /tmp/ipykernel_92593/2564248583.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pathway1 = row[0]
# /tmp/ipykernel_92593/2564248583.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pathway2 = row[2]
# /tmp/ipykernel_92593/2564248583.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   interaction = row[1]
# /tmp/ipykernel_92593/2564248583.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'source'] = row[0]
# /tmp/ipykernel_92593/2564248583.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'interaction'] = row[1]
# /tmp/ipykernel_92593/2564248583.py:61: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'target'] = row[2]
# /tmp/ipykernel_92593/2564248583.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   key = f'{str(row[0])}-<>{str(row[2])}'
# /tmp/ipykernel_92593/2564248583.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'source'] = row[0]
# /tmp/ipykernel_92593/2564248583.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'interaction'] = row[1]
# /tmp/ipykernel_92593/2564248583.py:61: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'target'] = row[2]
# /tmp/ipykernel_92593/2564248583.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   key = f'{str(row[0])}-<>{str(row[2])}'
# /tmp/ipykernel_92593/2564248583.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'source'] = row[0]
# /tmp/ipykernel_92593/2564248583.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'interaction'] = row[1]
# /tmp/ipykernel_92593/2564248583.py:61: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'target'] = row[2]
# /tmp/ipykernel_92593/2564248583.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   key = f'{str(row[0])}-<>{str(row[2])}'
# /tmp/ipykernel_92593/2564248583.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'source'] = row[0]
# /tmp/ipykernel_92593/2564248583.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'interaction'] = row[1]
# /tmp/ipykernel_92593/2564248583.py:61: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'target'] = row[2]
# /tmp/ipykernel_92593/2564248583.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   key = f'{str(row[0])}-<>{str(row[2])}'
# 90
# {'R-HSA-70171-<>R-HSA-70326': 0, 'R-HSA-70263-<>R-HSA-70326': 0, 'R-HSA-170822-<>R-HSA-70171': 0.05661541814888345, 'R-HSA-9634600-<>R-HSA-70171': 0.05661541814888345}
#           source                 interaction       target    weight
# 0    R-HSA-70171  abstraction:IsAComponentOf  R-HSA-70326  0.000000
# 1    R-HSA-70263  abstraction:IsAComponentOf  R-HSA-70326  0.000000
# 2   R-HSA-170822  abstraction:IsAComponentOf  R-HSA-70171  0.056615
# 3  R-HSA-9634600  abstraction:IsAComponentOf  R-HSA-70171  0.056615
#         source                  interaction         target    weight
# 0  R-HSA-70171  abstraction:NextStepPathway  R-HSA-9634600  0.056615
# 1  R-HSA-70263  abstraction:NextStepPathway    R-HSA-70171  0.000000
# /tmp/ipykernel_92593/2564248583.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[1] == "abstraction:NextStepPathway":
# /tmp/ipykernel_92593/2564248583.py:78: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Pathway1 = row[0]
# /tmp/ipykernel_92593/2564248583.py:79: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Pathway2 = row[2]
# /tmp/ipykernel_92593/2564248583.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[1] == "abstraction:NextStepPathway":
# /tmp/ipykernel_92593/2564248583.py:89: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'source'] = row[0]
# /tmp/ipykernel_92593/2564248583.py:90: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'interaction'] = row[1]
# /tmp/ipykernel_92593/2564248583.py:91: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'target'] = row[2]
# /tmp/ipykernel_92593/2564248583.py:92: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   key = f"{str(row[0])}->{str(row[2])}"
# /tmp/ipykernel_92593/2564248583.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[1] == "abstraction:NextStepPathway":
# /tmp/ipykernel_92593/2564248583.py:89: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'source'] = row[0]
# /tmp/ipykernel_92593/2564248583.py:90: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'interaction'] = row[1]
# /tmp/ipykernel_92593/2564248583.py:91: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   weighted_graph.at[counter_rows, 'target'] = row[2]
# /tmp/ipykernel_92593/2564248583.py:92: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   key = f"{str(row[0])}->{str(row[2])}"

# %%
process.kill()
time.sleep(30)
